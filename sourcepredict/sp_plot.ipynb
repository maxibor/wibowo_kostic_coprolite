# %%
import pandas as pd
from plotnine import *

# %%
embed = pd.read_csv("wib_embedding.csv", index_col=0)

# %%
ggplot(embed, aes(x='PC1',y='PC2', color='labels')) + geom_point() + theme_classic()
# Out:
# <ggplot: (-9223363244571128930)>

# %%
embed.labels.value_counts()
# Out:
# non_westernized_humans    100
# westernized_humans        100
# sink                       11
# archeo_sediment             8
# Name: labels, dtype: int64

# %%
pred = pd.read_csv("wib_sink.sourcepredict.csv", index_col=0)

# %%
pred = pred.T.reset_index().melt(id_vars='index', var_name='source')

# %%
pred.head()
# Out:
#     index           source     value
# 0  Lib4_3  archeo_sediment  0.041115
# 1  Lib4_7  archeo_sediment  0.049248
# 2    s_02  archeo_sediment  0.047070
# 3  Lib3_6  archeo_sediment  0.034319
# 4  Lib4_6  archeo_sediment  0.034534

# %%
ggplot(pred, aes(x='index',y='value', fill='source')) + geom_bar(position='fill', stat='identity')
# Out:
# <ggplot: (-9223363244571135828)>
